# %% [markdown]
# # OpenBB Provider Demo
# Run options-surface-edge-engine with yfinance primary and OpenBB fallback.

# %%
from options_surface_edge_engine.pipeline import run_scan
from options_surface_edge_engine.utils.config import EngineConfig

# %%
config = EngineConfig(provider_order=['yfinance', 'openbb'], openbb_provider='yfinance')
result = run_scan(['SPY', 'QQQ', 'GLD', 'NVDA'], config=config)
result.ranked_trades.head(10)
